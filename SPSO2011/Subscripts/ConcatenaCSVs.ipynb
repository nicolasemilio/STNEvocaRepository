# %%
#Pres = ['1stPres', '2ndPres', '3rdPres']
Pres = ['L1','L2','L3']

Folder = 'STN_EvPS{}'

Set = ['HYB','MUL','UNI']

Pop = ['10', '20', '50']

#RutaEjemplo: 1stPres/STN_EvPS10/P10_EVOCA.log_GA_FALL_S.out


#Crear dentro de 1stPres -> Crear STN_P10/ y dentro crear una carpeta por categoria
#copiar el archivo que corresponde
#hacer Rscript Create.R nombreCarpeta 1
#hacer Rscript metrics-alg.R nombreCarpeta-stn cat

Prefix_file = 'P{}_'

files = ['EVOCA.log_GA_FALL_S',
'EVOCA.log_GA_Fnk_2_20_S',
'EVOCA.log_GA_Fnk_2_38_S',
'EVOCA.log_GA_Fnk_2_52_S',
'EVOCA.log_GA_Fnk_3_20_S',
'EVOCA.log_GA_Fnk_3_34_S',
'EVOCA.log_GA_Fnk_3_48_S',
'EVOCA.log_GA_Fnk_4_20_S',
'EVOCA.log_GA_Fnk_4_30_S',
'EVOCA.log_GA_Fnk_4_40_S',
'EVOCA.log_GA_Fnk_5_20_S',
'EVOCA.log_GA_Fnk_5_28_S',
'EVOCA.log_GA_Fnk_5_38_S',
'EVOCA.log_GA_Fnk_6_20_S',
'EVOCA.log_GA_Fnk_6_26_S',
'EVOCA.log_GA_Fnk_6_32_S']

categories = ['ALL', '2_20', '2_38', '2_52', '3_20', '3_34', '3_48', '4_20', '4_30', '4_40','5_20','5_28','5_38','6_20','6_26','6_32']

# %%
import pandas as pd
import os


csv_files = []
for precision in Pres:
    for insset in Set:
        for PS in Pop: 
            cont = 0 #RutaEjemplo: L1/HYB/10/log_set-HYB_tam-10_L1_rev.txt
            #workpath = precision+'/STN_P'+PS
            folder_path = "STNMetrics/" + precision + "_" + insset + "_" + PS+"metrics"
            all_files = os.listdir(folder_path)
            path = folder_path+'/'+all_files[0]
            csv_files.append(path)

df_list = []

for csv in csv_files:
    try:
        # Try reading the file using default UTF-8 encoding
        df = pd.read_csv(csv)
        df_list.append(df)
    except UnicodeDecodeError:
        try:
            # If UTF-8 fails, try reading the file using UTF-16 encoding with tab separator
            df = pd.read_csv(file_path, sep='\t', encoding='utf-16')
            df_list.append(df)
        except Exception as e:
            print(f"Could not read file {csv} because of error: {e}")
    except Exception as e:
        print(f"Could not read file {csv} because of error: {e}")

# Concatenate all data into one DataFrame
big_df = pd.concat(df_list, ignore_index=True)

# Save the final result to a new CSV file
#big_df.to_csv(os.path.join(folder_path, 'combined_file.csv'), index=False)
big_df.to_csv('combined_file.csv', index=False)
print(csv_files)
# Out:
# ['STNMetrics/L1_HYB_10metrics/L1_HYB_10-metrics.csv', 'STNMetrics/L1_HYB_20metrics/L1_HYB_20-metrics.csv', 'STNMetrics/L1_HYB_50metrics/L1_HYB_50-metrics.csv', 'STNMetrics/L1_MUL_10metrics/L1_MUL_10-metrics.csv', 'STNMetrics/L1_MUL_20metrics/L1_MUL_20-metrics.csv', 'STNMetrics/L1_MUL_50metrics/L1_MUL_50-metrics.csv', 'STNMetrics/L1_UNI_10metrics/L1_UNI_10-metrics.csv', 'STNMetrics/L1_UNI_20metrics/L1_UNI_20-metrics.csv', 'STNMetrics/L1_UNI_50metrics/L1_UNI_50-metrics.csv', 'STNMetrics/L2_HYB_10metrics/L2_HYB_10-metrics.csv', 'STNMetrics/L2_HYB_20metrics/L2_HYB_20-metrics.csv', 'STNMetrics/L2_HYB_50metrics/L2_HYB_50-metrics.csv', 'STNMetrics/L2_MUL_10metrics/L2_MUL_10-metrics.csv', 'STNMetrics/L2_MUL_20metrics/L2_MUL_20-metrics.csv', 'STNMetrics/L2_MUL_50metrics/L2_MUL_50-metrics.csv', 'STNMetrics/L2_UNI_10metrics/L2_UNI_10-metrics.csv', 'STNMetrics/L2_UNI_20metrics/L2_UNI_20-metrics.csv', 'STNMetrics/L2_UNI_50metrics/L2_UNI_50-metrics.csv', 'STNMetrics/L3_HYB_10metrics/L3_HYB_10-metrics.csv', 'STNMetrics/L3_HYB_20metrics/L3_HYB_20-metrics.csv', 'STNMetrics/L3_HYB_50metrics/L3_HYB_50-metrics.csv', 'STNMetrics/L3_MUL_10metrics/L3_MUL_10-metrics.csv', 'STNMetrics/L3_MUL_20metrics/L3_MUL_20-metrics.csv', 'STNMetrics/L3_MUL_50metrics/L3_MUL_50-metrics.csv', 'STNMetrics/L3_UNI_10metrics/L3_UNI_10-metrics.csv', 'STNMetrics/L3_UNI_20metrics/L3_UNI_20-metrics.csv', 'STNMetrics/L3_UNI_50metrics/L3_UNI_50-metrics.csv']

# %%
# replace with your folder's path
#folder_path = r'metrics_P_50/'



print(all_files)
# Filter out non-CSV files
csv_files = [f for f in all_files if f.endswith('.csv')]

# Create a list to hold the dataframes
df_list = []

for csv in csv_files:
    file_path = os.path.join(folder_path, csv)
    try:
        # Try reading the file using default UTF-8 encoding
        df = pd.read_csv(file_path)
        df_list.append(df)
    except UnicodeDecodeError:
        try:
            # If UTF-8 fails, try reading the file using UTF-16 encoding with tab separator
            df = pd.read_csv(file_path, sep='\t', encoding='utf-16')
            df_list.append(df)
        except Exception as e:
            print(f"Could not read file {csv} because of error: {e}")
    except Exception as e:
        print(f"Could not read file {csv} because of error: {e}")

# Concatenate all data into one DataFrame
big_df = pd.concat(df_list, ignore_index=True)

# Save the final result to a new CSV file
big_df.to_csv(os.path.join(folder_path, 'combined_file.csv'), index=False)
